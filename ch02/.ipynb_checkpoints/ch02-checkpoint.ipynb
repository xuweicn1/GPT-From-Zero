# %% [markdown]
# # 第二章 处理文本数据

# %% [markdown]
# ## 2.2 文本分词
# 分词工具：https://tiktokenizer.vercel.app/?model=gpt2

# %%
import os

import urllib.request  

url ='https://raw.githubusercontent.com/xuweicn1/GPT-From-Zero/refs/heads/ch02/ch02/the-verdict.txt'
file_path = 'the-verdict.txt'

if not os.path.exists('the-verdict.txt'):
    urllib.request.urlretrieve(url, file_path)

with open(file_path, 'r') as f:
    raw_text = f.read()

# %% [markdown]
# len(raw_text)

# %% [markdown]
# 目标： 将20479 个单词分割成独立的单词和特殊字符，方便之后将他们转换为嵌入向量

# %%
import re
text = 'Hello, world. This, is a test.'
result = re.split(r'(\s)',text)

# %%
result
# Out:
# ['Hello,', ' ', 'world.', ' ', 'This,', ' ', 'is', ' ', 'a', ' ', 'test.']

# %% [markdown]
# 修正算法

# %%
text = 'Hello, world. This, is a test.'
result = re.split(r'([,.]|\s)',text)

# %%
result
# Out:
# ['Hello',
#  ',',
#  '',
#  ' ',
#  'world',
#  '.',
#  '',
#  ' ',
#  'This',
#  ',',
#  '',
#  ' ',
#  'is',
#  ' ',
#  'a',
#  ' ',
#  'test',
#  '.',
#  '']

# %%
text = 'Hello, world. Is This-- is a test?'
result = re.split(r'([,.:;?_!"()\']|--|\s)',text)

# %%
result
# Out:
# ['Hello',
#  ',',
#  '',
#  ' ',
#  'world',
#  '.',
#  '',
#  ' ',
#  'Is',
#  ' ',
#  'This',
#  '--',
#  '',
#  ' ',
#  'is',
#  ' ',
#  'a',
#  ' ',
#  'test',
#  '?',
#  '']

# %%
result = [item.strip() for item in result if item.strip()]

# %%
result
# Out:
# ['Hello', ',', 'world', '.', 'Is', 'This', '--', 'is', 'a', 'test', '?']

# %%
prosessed = re.split(r'([,.:;?_!"()\']|--|\s)',raw_text)

# %%
prosessed = [item.strip() for item in prosessed if item.strip()]

# %%
len(prosessed)
# Out:
# 4690

# %%
prosessed[:30]
# Out:
# ['I',
#  'HAD',
#  'always',
#  'thought',
#  'Jack',
#  'Gisburn',
#  'rather',
#  'a',
#  'cheap',
#  'genius',
#  '--',
#  'though',
#  'a',
#  'good',
#  'fellow',
#  'enough',
#  '--',
#  'so',
#  'it',
#  'was',
#  'no',
#  'great',
#  'surprise',
#  'to',
#  'me',
#  'to',
#  'hear',
#  'that',
#  ',',
#  'in']

# %% [markdown]
# ## 2.3 将词元转换为词元ID

# %%
all_words = sorted(set(prosessed))
vocab_size = len(all_words)

# %%
vocab_size
# Out:
# 1130

# %% [markdown]
# 创建词汇表

# %%
vocab = {token:inter for inter,token in enumerate(all_words)}

# %% [markdown]
# 实现简单的文本分词器

# %%
class SimpleTokenizerV1:
    def __init__(self, vocab=None):
        """
        vocab: 字符串到整数的映射，例如 {'A': 11, 'Ah': 12, 'Among': 13}

        """
        self.str_to_init = vocab
        # 反转字典，得到 init_to_str 示例： {11: 'A', 12: 'Ah', 13: 'Among'}
        self.init_to_str = {v: k for k, v in vocab.items()}

    def encode(self, text):
        """
        将输入文本转换为整数列表
        """
        prosessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
        prosessed = [item.strip() for item in prosessed if item.strip()]
        ids = [self.str_to_init[s] for s in prosessed]
        return ids

    def decode(self, ids):
        """
        将整数列表转换回文本
        """

        text = " ".join([self.init_to_str[i] for i in ids])
        text = re.sub(r'\s+([,.?!"()\'])', r"\1", text)

        return text

# %%
tokenizer = SimpleTokenizerV1(vocab)

# %%
text = """"It's the last he painted,you know,"
Mrs. Gisburn said with pardonable pride. """

# %%
ids= tokenizer.encode(text)
print(ids)
# Out:
# [1, 56, 2, 850, 988, 602, 533, 746, 5, 1126, 596, 5, 1, 67, 7, 38, 851, 1108, 754, 793, 7]

# %%
print(tokenizer.decode(ids))
# Out:
# " It' s the last he painted, you know," Mrs. Gisburn said with pardonable pride.

# %% [markdown]
# ## 2.4 特殊上下文词元处理

# %%
text = "Hello, do you like tea"
print(tokenizer.encode(text))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 text = "Hello, do you like tea"
# ----> 2 print(tokenizer.encode(text))
#
# Cell In[52], line 17, in SimpleTokenizerV1.encode(self, text)
#      13         将输入文本转换为整数列表
#      14         """
#      15         prosessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
#      16         prosessed = [item.strip() for item in prosessed if item.strip()]
# ---> 17         ids = [self.str_to_init[s] for s in prosessed]
#      18         return ids
#
# KeyError: 'Hello'

# %% [markdown]
# 报错原因是我们的词汇表中并没有Hello这个词

# %%
all_tokens =sorted(list(set(prosessed)))
all_tokens.extend(["<|endoftext|>","<|unk|>"])
vocab = {token:inter for inter,token in enumerate(all_tokens)}

# %%
len(vocab)
# Out:
# 1132

# %%
for i,item  in enumerate(list(vocab.items())[-5:]):
    print(item)
# Out:
# ('younger', 1127)
# ('your', 1128)
# ('yourself', 1129)
# ('<|endoftext|>', 1130)
# ('<|unk|>', 1131)

# %% [markdown]
# 优化代码，使他能够处理位置单词的文本分词器

# %%
class SimpleTokenizerV2:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = { i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
        preprocessed = [item.strip() for item in preprocessed if item.strip()]
        preprocessed = [
            item if item in self.str_to_int 
            else "<|unk|>" for item in preprocessed
        ]

        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.:;?!"()\'])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizerV2(vocab)

# %%
tokenizer.encode(text)
# Out:
# [1131, 5, 355, 1126, 628, 975]

# %%
tokenizer.decode(tokenizer.encode(text))
# Out:
# '<|unk|>, do you like tea'

# %%
text1 = "Hello, do you like tea?"
text2 = "In the sunlit terraces of the palace."

text = " <|endoftext|> ".join((text1, text2))

print(text)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terraces of the palace.

# %%
tokenizer.encode(text)
# Out:
# [1131, 5, 355, 1126, 628, 975, 10, 1130, 55, 988, 956, 984, 722, 988, 1131, 7]

# %%
tokenizer.decode(tokenizer.encode(text))
# Out:
# '<|unk|>, do you like tea? <|endoftext|> In the sunlit terraces of the <|unk|>.'
